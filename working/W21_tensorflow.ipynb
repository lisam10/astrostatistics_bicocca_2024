# %% [markdown]
# ![](W21_tensorflow_0.png)

# %% [markdown]
# - Data augmentation: add $x_1x_2$ as an input
# - Number of layers: use between twice the number of input features (6) and a number between the input and output nodes (respectively 3 and 1) -> use 3 units
# - Other hyperparameters were found just by trial and error

# %% [markdown]
# ## Spiral
# ### Need an least an additional layer since it is not a linear problem:
# ![](W21_tensorflow_1.png)

# %% [markdown]
# ### An a similar result with one more layer:
# ![](W21_tensorflow_2.png)
