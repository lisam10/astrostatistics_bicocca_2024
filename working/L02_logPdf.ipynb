# %% [markdown]
# # Pdf of the log
#
# 1. Use numpy to draw $N$ (where $N$ is large...) random samples from a uniform distribution between 0.1 and 10, and store these samples as $x$.
# 2. Use matplotlib to make a histogram of these samples.
# 3. Compute the base-10 log of your array $x$, and store this as $y$.
# 4. Make another histogram for $y$. Using the equation to transform probability distributions, write what the theoretical pdf of $y$ is, and overplot it onto your histogram.
# 5. Compute the log of the mean of $x$ and the mean of $y$. Now compute the log of the median of $x$ and the median of $y$.

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_n = 10000
min = 0.1
max = 10

x = np.random.uniform (min, max, sample_n)

plt.hist(x, density = True, histtype='step',)
plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.title('Histogram of uniform distribution')
# Out:
# Text(0.5, 1.0, 'Histogram of uniform distribution')

# %% [markdown]
# We can find the theoretical pdf of y by using $ p(y) = |\frac{dx}{dy}| p(x) = |\frac{d(10^y)}{dy}|p(x) = p(x) \cdot 10^y \cdot ln(10)$

# %%
y = np.log10(x)
    
plt.hist(y, density = True, histtype = 'step')
plt.xlabel('y')
plt.ylabel('$f(y)$')
plt.title('Histogram of log10 distribution')

y.sort()
z =  1 / (max - min) * np.log(10) * np.power(10, y)
plt.plot(y, z)

print("\n x log 10 mean = ", np.log10(np.mean(x)), "\n y mean = ", np.mean(y))
print("\n x log 10 median = ", np.log10(np.median(x)), "\n y median = ", np.median(y))
# Out:
#  x log 10 mean =  0.7065504190983544
#  y mean =  0.5910484181007698
#
#  x log 10 median =  0.7043946874176082
#  y median =  0.7043946864947809
