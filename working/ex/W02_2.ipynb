# %% [markdown]
# ### Pdf of the log

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Use `numpy` to draw $N$ (where $N$ is large...) random samples from a uniform distribution between $0.1$ and $10$, and store these samples as $x$.
# 2. Use matplotlib to make a histogram of these samples.

# %%
N = 1000
x = np.random.uniform(0.1, 10, N)

plt.hist(x, bins = int(np.sqrt(N)), histtype = 'step')
plt.title('x histogram')
plt.show()

# %% [markdown]
# 3. Compute the base-10 log of your array $x$, and store this as $y$.
# 4. Make another histogram for $y$. Using the equation to transform probability distributions, write what the theoretical pdf of $y$ is, and overplot it onto your histogram.

# %% [markdown]
# Given $y = \mathrm{log}_{10}(x)$, $dx/dy = 10^y \cdot \mathrm{ln}(10)$ and $p(x) = 1/(10 -0.1)$ for $x \in [0.1, 10]$:
# $$p(y) = |\frac{dx}{dy}| \cdot p(x) = \frac{1}{9.9} 10^y \cdot \mathrm{ln}(10) \, \, \, \, \mathrm{for } \,\,\,\ y \in [-1, 1]$$

# %%
def pdf_y(y):
    return (np.log(10) * 10**y) / 9.9

# %%
y = np.log10(x)

plt.hist(y, bins = int(np.sqrt(N)), density = 'True', histtype = 'step', facecolor = 'C0')
plt.scatter(y, pdf_y(y), label = r'$p(y)$', s = 3)
plt.title('y histogram')
plt.legend()
plt.show()

# %% [markdown]
# 5. Compute the log of the mean of $x$ and the mean of $y$. Now compute the log of the median of $x$ and the median of $y$.

# %%
print('log(x̄) = ', np.log10(np.mean(x)), ', ȳ = ', np.mean(y))
# Out:
# log(x̄) =  0.714226281463919 , ȳ =  0.6011964390524761

# %%
print('log(med(x)) = ', np.log10(np.median(x)), ', med(y) = ', np.median(y))
# Out:
# log(med(x)) =  0.7155901165347271 , med(y) =  0.7155897439794848
